# %%
# %pip install --upgrade --quiet  langchain langchain-community langchain-openai langchain-experimental neo4j wikipedia tiktoken yfiles_jupyter_graphs
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 38.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 78.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.6/296.6 kB 23.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 59.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.6/15.6 MB 91.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.4/404.4 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.7/383.7 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.2/325.2 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 12.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 81.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
#   Building wheel for wikipedia (setup.py) ... done

# %%
from langchain_core.runnables import (
    RunnableBranch,
    RunnableLambda,
    RunnableParallel,
    RunnablePassthrough,
)
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate
from langchain_core.messages import AIMessage, HumanMessage
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import ConfigurableField
from yfiles_jupyter_graphs import GraphWidget
from neo4j import GraphDatabase
import os
from langchain_community.vectorstores import Neo4jVector

# %%
OPENAI_API_KEY = "**"

# %%
NEO4J_URI="neo4j+s://fb698211.databases.neo4j.io"
NEO4J_USERNAME="neo4j"
NEO4J_PASSWORD="**"

# %%
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
os.environ["NEO4J_URI"] = NEO4J_URI
os.environ["NEO4J_USERNAME"] = NEO4J_USERNAME
os.environ["NEO4J_PASSWORD"] = NEO4J_PASSWORD

# %%
from langchain.document_loaders import WikipediaLoader
raw_documents = WikipediaLoader(query="Elizabeth II").load()
# Out:
# /usr/local/lib/python3.10/dist-packages/wikipedia/wikipedia.py:389: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 389 of the file /usr/local/lib/python3.10/dist-packages/wikipedia/wikipedia.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   lis = BeautifulSoup(html).find_all('li')

# %%
from langchain.text_splitter import TokenTextSplitter
text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
documents = text_splitter.split_documents(raw_documents[:3])

# %%
from langchain_openai import ChatOpenAI
llm=ChatOpenAI(temperature=0, model_name="gpt-3.5-turbo")

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
llm_transformer = LLMGraphTransformer(llm=llm)

# %%
graph_documents = llm_transformer.convert_to_graph_documents(documents)

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Elizabeth Ii', type='Person', properties={}), Node(id='United Kingdom', type='Location', properties={}), Node(id='Commonwealth Realms', type='Organization', properties={}), Node(id='King George V', type='Person', properties={}), Node(id='Duke And Duchess Of York', type='Person', properties={}), Node(id='King George Vi', type='Person', properties={}), Node(id='Queen Elizabeth The Queen Mother', type='Person', properties={}), Node(id='Edward Viii', type='Person', properties={}), Node(id='Auxiliary Territorial Service', type='Organization', properties={}), Node(id='Philip Mountbatten', type='Person', properties={}), Node(id='Charles', type='Person', properties={}), Node(id='Anne', type='Person', properties={}), Node(id='Andrew', type='Person', properties={}), Node(id='Edward', type='Person', properties={}), Node(id='Canada', type='Location', properties={}), Node(id='Australia', type='Location', properties={}), Node(id='New Zealand', type='Location', properties={}), Node(id='South Africa', type='Location', properties={}), Node(id='Pakistan', type='Location', properties={}), Node(id='Ceylon', type='Location', properties={}), Node(id='China', type='Location', properties={}), Node(id='Russia', type='Location', properties={}), Node(id='Republic Of Ireland', type='Location', properties={}), Node(id='Diana', type='Person', properties={})], relationships=[Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='United Kingdom', type='Location', properties={}), type='QUEEN', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Commonwealth Realms', type='Organization', properties={}), type='QUEEN', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='King George V', type='Person', properties={}), type='GRANDDAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Duke And Duchess Of York', type='Person', properties={}), type='DAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='King George Vi', type='Person', properties={}), type='DAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Queen Elizabeth The Queen Mother', type='Person', properties={}), type='DAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Edward Viii', type='Person', properties={}), type='NIECE', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Auxiliary Territorial Service', type='Organization', properties={}), type='MEMBER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Philip Mountbatten', type='Person', properties={}), type='SPOUSE', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Charles', type='Person', properties={}), type='MOTHER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Anne', type='Person', properties={}), type='MOTHER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Andrew', type='Person', properties={}), type='MOTHER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Edward', type='Person', properties={}), type='MOTHER', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Canada', type='Location', properties={}), type='QUEEN', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Australia', type='Location', properties={}), type='QUEEN', properties={}), Relationship(source=Node ...
#  GraphDocument(nodes=[Node(id='Elizabeth', type='Person', properties={}), Node(id='Diana', type='Person', properties={}), Node(id='Charles Iii', type='Person', properties={}), Node(id='Prince Albert, Duke Of York', type='Person', properties={}), Node(id='Elizabeth, Duchess Of York', type='Person', properties={}), Node(id='King George V', type='Person', properties={}), Node(id='Queen Mary', type='Person', properties={}), Node(id='Claude Bowes-Lyon, 14Th Earl Of Strathmore And Kinghorne', type='Person', properties={}), Node(id='Cosmo Gordon Lang', type='Person', properties={}), Node(id='George V', type='Person', properties={}), Node(id='Princess Margaret', type='Person', properties={}), Node(id='Marion Crawford', type='Person', properties={}), Node(id='Balmoral Castle', type='Location', properties={}), Node(id='17 Bruton Street In Mayfair', type='Location', properties={}), Node(id='Buckingham Palace', type='Location', properties={}), Node(id='United Kingdom', type='Location', properties={})], relationships=[Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Diana', type='Person', properties={}), type='FORMER_DAUGHTER_IN_LAW', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Charles Iii', type='Person', properties={}), type='MOTHER', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Prince Albert, Duke Of York', type='Person', properties={}), type='DAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Elizabeth, Duchess Of York', type='Person', properties={}), type='DAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Claude Bowes-Lyon, 14Th Earl Of Strathmore And Kinghorne', type='Person', properties={}), type='GRANDDAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='George V', type='Person', properties={}), type='GRANDDAUGHTER', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Princess Margaret', type='Person', properties={}), type='SISTER', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Balmoral Castle', type='Location', properties={}), type='DIED_AT', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='17 Bruton Street In Mayfair', type='Location', properties={}), type='BORN_AT', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='Buckingham Palace', type='Location', properties={}), type='BAPTISED_AT', properties={}), Relationship(source=Node(id='Elizabeth', type='Person', properties={}), target=Node(id='United Kingdom', type='Location', properties={}), type='POPULAR_IN', properties={})], source=Document(metadata={'title': 'Elizabeth II', 'summary': "Elizabeth II (Elizabeth Alexandra Mary; 21 April 1926 – 8 September 2022) was Queen of the United Kingdom and other Commonwealth realms from 6 February 1952 until her death in 2022. She had been queen regnant of 32 sovereign states during her lifetime and was the monarch of 15 realms at her death. Her reign of 70 years and 214 days is the longest of any British monarch and the second-longest of any sovereign state.\nElizabeth was born in Mayfair, London, during the reign of her paternal grandfather, King George V. She was the first child of the Duke and Duchess of York (later King George VI and Queen Elizabeth The Queen Mother). Her father acceded to the throne in 1936 upon the abdication of his brother Edward VIII, making the ten-year-old Princess Elizabeth the heir presumptive. She was educated privately at home and began to undertake public duties during the Second World War, serving in the Auxiliary Territorial Service. In November 1947,  ...
#  GraphDocument(nodes=[Node(id='Elizabeth Ii', type='Person', properties={}), Node(id='United Kingdom', type='Location', properties={}), Node(id='Commonwealth Realms', type='Organization', properties={}), Node(id='8 September 2022', type='Date', properties={}), Node(id='Balmoral Castle', type='Location', properties={}), Node(id='Scotland', type='Location', properties={}), Node(id='96', type='Age', properties={}), Node(id='70 Years And 214 Days', type='Duration', properties={}), Node(id='Charles Iii', type='Person', properties={}), Node(id='Operation London Bridge', type='Event', properties={}), Node(id='Operation Unicorn', type='Event', properties={}), Node(id="St Giles' Cathedral", type='Location', properties={}), Node(id='Edinburgh', type='Location', properties={}), Node(id='12 To 13 September', type='Date', properties={}), Node(id='London', type='Location', properties={}), Node(id='Westminster Hall', type='Location', properties={}), Node(id='14 To 19 September', type='Date', properties={}), Node(id='33,000 People', type='Population', properties={}), Node(id='250,000 People', type='Population', properties={}), Node(id='Ten Days', type='Duration', properties={}), Node(id='19 September', type='Date', properties={}), Node(id='Winston Churchill', type='Person', properties={}), Node(id='1965', type='Date', properties={}), Node(id='Westminster Abbey', type='Location', properties={}), Node(id='Wellington Arch', type='Location', properties={}), Node(id='3,000 Military Personnel', type='Population', properties={}), Node(id='One Million People', type='Population', properties={}), Node(id='Windsor', type='Location', properties={}), Node(id='Windsor Great Park', type='Location', properties={}), Node(id="St George'S Chapel", type='Location', properties={}), Node(id='Windsor Castle', type='Location', properties={}), Node(id='Prince Philip', type='Person', properties={}), Node(id='King George Vi Memorial Chapel', type='Location', properties={}), Node(id='Public Holiday', type='Event', properties={}), Node(id='Commonwealth States', type='Organization', properties={}), Node(id='Prince William', type='Person', properties={}), Node(id='Catherine Middleton', type='Person', properties={}), Node(id='21St Century', type='Time_period', properties={}), Node(id='£162 Million', type='Amount', properties={}), Node(id='April 2021', type='Date', properties={}), Node(id='Walking Stick', type='Object', properties={}), Node(id='October 2021', type='Date', properties={}), Node(id="King Edward Vii'S Hospital", type='Location', properties={}), Node(id='Northern Ireland', type='Location', properties={}), Node(id='Cop26 Summit', type='Event', properties={}), Node(id='Glasgow', type='Location', properties={}), Node(id='Sprained Back', type='Health_condition', properties={}), Node(id='November', type='Date', properties={})], relationships=[Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='United Kingdom', type='Location', properties={}), type='QUEEN_OF', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Commonwealth Realms', type='Organization', properties={}), type='QUEEN_OF', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='8 September 2022', type='Date', properties={}), type='DIED_ON', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Balmoral Castle', type='Location', properties={}), type='DIED_AT', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='96', type='Age', properties={}), type='AGE_AT_DEATH', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='70 Years And 214 Days', type='Duration', properties={}), type='REIGN_DURATION', properties={}), Relationship(source=Node(id='Elizabeth Ii', type='Person', properties={}), target=Node(id='Charle ...
#  GraphDocument(nodes=[Node(id='Northern Ireland', type='Location', properties={}), Node(id='Cop26 Summit', type='Event', properties={}), Node(id='Glasgow', type='Location', properties={}), Node(id='2021 National Service Of Remembrance', type='Event', properties={}), Node(id='Covid-19 Pandemic In England', type='Event', properties={}), Node(id='Queen', type='Person', properties={}), Node(id='Windsor Castle', type='Location', properties={}), Node(id='Covid-19', type='Disease', properties={}), Node(id='Service Of Thanksgiving For Prince Philip', type='Event', properties={}), Node(id='Westminster Abbey', type='Location', properties={}), Node(id='Commonwealth Day Service', type='Event', properties={}), Node(id='Royal Maundy Service', type='Event', properties={}), Node(id='State Opening Of Parliament', type='Event', properties={}), Node(id='National Service Of Thanksgiving For Her Platinum Jubilee', type='Event', properties={}), Node(id='Trooping The Colour', type='Event', properties={}), Node(id='Douglas Glass', type='Person', properties={}), Node(id='Scotland', type='Location', properties={})], relationships=[Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Northern Ireland', type='Location', properties={}), type='RELATED_TO', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Cop26 Summit', type='Event', properties={}), type='RELATED_TO', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='2021 National Service Of Remembrance', type='Event', properties={}), type='MISSED_DUE_TO_INJURY', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Covid-19 Pandemic In England', type='Event', properties={}), type='PARTICIPATED_IN', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Covid-19', type='Disease', properties={}), type='CONTRACTED', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Service Of Thanksgiving For Prince Philip', type='Event', properties={}), type='ATTENDED', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Commonwealth Day Service', type='Event', properties={}), type='MISSED_DUE_TO_HEALTH_ISSUES', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Royal Maundy Service', type='Event', properties={}), type='MISSED_DUE_TO_HEALTH_ISSUES', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='State Opening Of Parliament', type='Event', properties={}), type='MISSED_DUE_TO_HEALTH_ISSUES', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='National Service Of Thanksgiving For Her Platinum Jubilee', type='Event', properties={}), type='MISSED_DUE_TO_HEALTH_ISSUES', properties={}), Relationship(source=Node(id='Queen', type='Person', properties={}), target=Node(id='Douglas Glass', type='Person', properties={}), type='TREATED_BY', properties={})], source=Document(metadata={'title': 'Death and state funeral of Elizabeth II', 'summary': "Elizabeth II, Queen of the United Kingdom and the other Commonwealth realms, died on 8 September 2022 at Balmoral Castle in Scotland, at the age of 96. Elizabeth's reign of 70 years and 214 days was the longest of any British monarch. She was succeeded by her eldest son, Charles III.\nElizabeth's death set in motion the most recent version of Operation London Bridge, a funeral plan first devised in the 1960s, and Operation Unicorn, the plan for the Queen's death in Scotland. Elizabeth's coffin lay at rest in St Giles' Cathedral in Edinburgh from 12 to 13 September, after which it was flown to London, where it lay in state in Westminster Hall from 14 to 19 September. An estimated 33,000 people filed past the Queen's coffin in Edinburgh, ...
#  GraphDocument(nodes=[Node(id='Queen Elizabeth 2', type='Ship', properties={}), Node(id='Cunard Line', type='Company', properties={}), Node(id='Southampton, Uk', type='Location', properties={}), Node(id='New York, United States', type='Location', properties={}), Node(id='Queen Mary 2', type='Ship', properties={}), Node(id='Liverpool', type='Location', properties={}), Node(id='Clydebank, Scotland', type='Location', properties={}), Node(id='Project Genesis', type='Project', properties={}), Node(id='Micky Arison', type='Person', properties={}), Node(id='Carnival', type='Company', properties={}), Node(id='Carnival Uk', type='Company', properties={}), Node(id='Dubai World', type='Company', properties={}), Node(id='Palm Jumeirah, Dubai', type='Location', properties={}), Node(id='Dubai Drydocks', type='Location', properties={}), Node(id='Mina Rashid', type='Location', properties={}), Node(id='Port Rashid', type='Location', properties={}), Node(id='Oceanic Group', type='Company', properties={}), Node(id='Ahmed Sultan Bin Sulayem', type='Person', properties={}), Node(id='Dp World', type='Company', properties={})], relationships=[Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Cunard Line', type='Company', properties={}), type='OPERATED_BY', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Southampton, Uk', type='Location', properties={}), type='HOME_PORT', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='New York, United States', type='Location', properties={}), type='SERVICE_ROUTE', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Queen Mary 2', type='Ship', properties={}), type='SUCCEEDED_BY', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Clydebank, Scotland', type='Location', properties={}), type='BUILT_IN', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Dubai World', type='Company', properties={}), type='ACQUIRED_BY', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Palm Jumeirah, Dubai', type='Location', properties={}), type='MOORED_AT', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Mina Rashid', type='Location', properties={}), type='LAID_UP_AT', properties={}), Relationship(source=Node(id='Queen Elizabeth 2', type='Ship', properties={}), target=Node(id='Port Rashid', type='Location', properties={}), type='OPERATING_AT', properties={}), Relationship(source=Node(id='Cunard Line', type='Company', properties={}), target=Node(id='Micky Arison', type='Person', properties={}), type='PURCHASED_BY', properties={}), Relationship(source=Node(id='Cunard Line', type='Company', properties={}), target=Node(id='Project Genesis', type='Project', properties={}), type='ANNOUNCED', properties={}), Relationship(source=Node(id='Project Genesis', type='Project', properties={}), target=Node(id='Queen Mary 2', type='Ship', properties={}), type='RESULTED_IN', properties={}), Relationship(source=Node(id='Dubai World', type='Company', properties={}), target=Node(id='Ahmed Sultan Bin Sulayem', type='Person', properties={}), type='CHAIRED_BY', properties={})], source=Document(metadata={'title': 'Queen Elizabeth 2', 'summary': 'Queen Elizabeth 2 (QE2) is a retired British passenger ship converted into a floating hotel. Originally built for the Cunard Line, the ship was operated by Cunard as both a transatlantic liner and a cruise ship from 1969 to 2008. She was then laid up until converted and since 18 April 2018 has been operating as a floating hotel in Dubai.\nQueen Elizabeth 2 was designed for the transatlantic service from her home port of Southampton, UK, to New York, United States. ...
#  GraphDocument(nodes=[Node(id='2', type='Ship', properties={}), Node(id='Dubai-Based Construction Company', type='Company', properties={}), Node(id='18 April 2018', type='Date', properties={}), Node(id='1957', type='Date', properties={}), Node(id='Transatlantic Sea Travel', type='Concept', properties={}), Node(id='Air Transit', type='Concept', properties={}), Node(id='Boeing 707', type='Aircraft', properties={}), Node(id='Douglas Dc8', type='Aircraft', properties={}), Node(id='Queen Mary', type='Ship', properties={}), Node(id='Queen Elizabeth', type='Ship', properties={}), Node(id='Cunard', type='Company', properties={}), Node(id='North Atlantic Passenger Service', type='Service', properties={}), Node(id='Royal Mail Carrier', type='Service', properties={}), Node(id='Q3', type='Ship', properties={}), Node(id='19 October 1961', type='Date', properties={})], relationships=[Relationship(source=Node(id='Dubai-Based Construction Company', type='Company', properties={}), target=Node(id='2', type='Ship', properties={}), type='REFURBISHED', properties={}), Relationship(source=Node(id='2', type='Ship', properties={}), target=Node(id='18 April 2018', type='Date', properties={}), type='OPENED_TO_VISITORS', properties={}), Relationship(source=Node(id='Transatlantic Sea Travel', type='Concept', properties={}), target=Node(id='1957', type='Date', properties={}), type='DISPLACED_BY_AIR_TRANSIT', properties={}), Relationship(source=Node(id='Boeing 707', type='Aircraft', properties={}), target=Node(id='Douglas Dc8', type='Aircraft', properties={}), type='DEBUTED_IN_1958', properties={}), Relationship(source=Node(id='Cunard', type='Company', properties={}), target=Node(id='Queen Mary', type='Ship', properties={}), type='OPERATED', properties={}), Relationship(source=Node(id='Cunard', type='Company', properties={}), target=Node(id='Queen Elizabeth', type='Ship', properties={}), type='OPERATED', properties={}), Relationship(source=Node(id='Cunard', type='Company', properties={}), target=Node(id='North Atlantic Passenger Service', type='Service', properties={}), type='PROVIDED', properties={}), Relationship(source=Node(id='Cunard', type='Company', properties={}), target=Node(id='Royal Mail Carrier', type='Service', properties={}), type='PROVIDED', properties={}), Relationship(source=Node(id='Cunard', type='Company', properties={}), target=Node(id='Q3', type='Ship', properties={}), type='PLANNED_REPLACEMENT', properties={}), Relationship(source=Node(id='Q3', type='Ship', properties={}), target=Node(id='19 October 1961', type='Date', properties={}), type='PROJECT_CANCELLED', properties={})], source=Document(metadata={'title': 'Queen Elizabeth 2', 'summary': 'Queen Elizabeth 2 (QE2) is a retired British passenger ship converted into a floating hotel. Originally built for the Cunard Line, the ship was operated by Cunard as both a transatlantic liner and a cruise ship from 1969 to 2008. She was then laid up until converted and since 18 April 2018 has been operating as a floating hotel in Dubai.\nQueen Elizabeth 2 was designed for the transatlantic service from her home port of Southampton, UK, to New York, United States. She served as the flagship of the line from 1969 until succeeded by Queen Mary 2 in 2004. Queen Elizabeth 2 was designed in Cunard\'s offices in Liverpool and Southampton and built in Clydebank, Scotland. She was considered the last of the transatlantic ocean liners until "Project Genesis" was announced by Cunard Line in 1995 after the business purchase of Cunard by Micky Arison; chairman of Carnival and Carnival UK. Project Genesis was intended to create new life in the ocean liner saga, and in 1998, Cunard revealed the name: RMS Queen Mary 2.\nQueen Elizabeth 2 was refitted with a modern diesel powerplant in 1986–87. She undertook regular world cruises during almost 40 years of service, and later operated predominantly as a cruise ship, sailing out of Southampton, England. Queen Elizabeth 2 had no running mate and never ran a year-rou ...

# %%
from langchain_community.graphs import Neo4jGraph
graph = Neo4jGraph()

# %%
graph.add_graph_documents(
    graph_documents,
    baseEntityLabel=True,
    include_source=True
)

# %%
default_cypher = "MATCH (s)-[r:!MENTIONS]->(t) RETURN s,r,t LIMIT 50"

# %%
from yfiles_jupyter_graphs import GraphWidget
from neo4j import GraphDatabase

# %%
try:
  import google.colab
  from google.colab import output
  output.enable_custom_widget_manager()
except:
  pass

# %%
def showGraph(cypher: str = default_cypher):
    # create a neo4j session to run queries
    driver = GraphDatabase.driver(
        uri = os.environ["NEO4J_URI"],
        auth = (os.environ["NEO4J_USERNAME"],
                os.environ["NEO4J_PASSWORD"]))
    session = driver.session()
    widget = GraphWidget(graph = session.run(cypher).graph())
    widget.node_label_mapping = 'id'
    display(widget)
    return widget

# %%
showGraph()
# Out:
# GraphWidget(layout=Layout(height='800px', width='100%'))
# GraphWidget(layout=Layout(height='800px', width='100%'))

# %%
from typing import Tuple, List, Optional
from langchain_community.vectorstores import Neo4jVector

# %%
from langchain_openai import OpenAIEmbeddings
vector_index = Neo4jVector.from_existing_graph(
    OpenAIEmbeddings(),
    search_type="hybrid",
    node_label="Document",
    text_node_properties=["text"],
    embedding_node_property="embedding"
)

# %%
from langchain_core.pydantic_v1 import BaseModel, Field
# Extract entities from text
class Entities(BaseModel):
    """Identifying information about entities."""

    names: List[str] = Field(
        ...,
        description="All the person, organization, or business entities that "
        "appear in the text",
    )

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.prompts.prompt import PromptTemplate

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are extracting organization and person entities from the text.",
        ),
        (
            "human",
            "Use the given format to extract information from the following "
            "input: {question}",
        ),
    ]
)

# %%
entity_chain = prompt | llm.with_structured_output(Entities)

# %%
entity_chain.invoke({"question": "Where was Victoria born?"}).names
# Out:
# ['Victoria']

# %%
from langchain_community.vectorstores.neo4j_vector import remove_lucene_chars

# %%
def generate_full_text_query(input: str) -> str:
    full_text_query = ""
    words = [el for el in remove_lucene_chars(input).split() if el]
    for word in words[:-1]:
        full_text_query += f" {word}~2 AND"
    full_text_query += f" {words[-1]}~2"
    return full_text_query.strip()

# %%
# Fulltext index query
def structured_retriever(question: str) -> str:
    result = ""
    entities = entity_chain.invoke({"question": question})
    for entity in entities.names:
        response = graph.query(
            """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
            YIELD node,score
            CALL {
              WITH node
              MATCH (node)-[r:!MENTIONS]->(neighbor)
              RETURN node.id + ' - ' + type(r) + ' -> ' + neighbor.id AS output
              UNION ALL
              WITH node
              MATCH (node)<-[r:!MENTIONS]-(neighbor)
              RETURN neighbor.id + ' - ' + type(r) + ' -> ' +  node.id AS output
            }
            RETURN output LIMIT 50
            """,
            {"query": generate_full_text_query(entity)},
        )
        result += "\n".join([el['output'] for el in response])
    return result

# %%
print(structured_retriever("Who is Elizabeth Ii ?"))
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# <ipython-input-46-dcc8ca040b19> in <cell line: 1>()
# ----> 1 print(structured_retriever("Who is Elizabeth Ii ?"))
#
# <ipython-input-39-d9ce21ac4866> in structured_retriever(question)
#       4     entities = entity_chain.invoke({"question": question})
#       5     for entity in entities.names:
# ----> 6         response = graph.query(
#       7             """CALL db.index.fulltext.queryNodes('entity', $query, {limit:2})
#       8             YIELD node,score
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/graphs/neo4j_graph.py in query(self, query, params)
#     429
#     430         try:
# --> 431             data, _, _ = self._driver.execute_query(
#     432                 Query(text=query, timeout=self.timeout),
#     433                 database=self._database,
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/driver.py in execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     969                 )
#     970             with session._pipelined_begin:
# --> 971                 return session._run_transaction(
#     972                     access_mode,
#     973                     TelemetryAPI.DRIVER,
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/work/session.py in _run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     572                 tx = self._transaction
#     573                 try:
# --> 574                     result = transaction_function(tx, *args, **kwargs)
#     575                 except asyncio.CancelledError:
#     576                     # if cancellation callback has not been called yet:
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_work/query.py in wrapped(*args, **kwargs)
#     142     def wrapper(f):
#     143         def wrapped(*args, **kwargs):
# --> 144             return f(*args, **kwargs)
#     145
#     146         wrapped.metadata = metadata
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/driver.py in _work(tx, query, parameters, transformer)
#    1306 ) -> _T:
#    1307     res = tx.run(query, parameters)
# -> 1308     return transformer(res)
#    1309
#    1310
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/work/result.py in to_eager_result(self)
#     795         .. versionchanged:: 5.8 Stabilized from experimental.
#     796         """
# --> 797         self._buffer_all()
#     798         return EagerResult(
#     799             keys=list(self.keys()),
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/work/result.py in _buffer_all(self)
#     452
#     453     def _buffer_all(self):
# --> 454         self._buffer()
#     455
#     456     def _obtain_summary(self) -> ResultSummary:
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/work/result.py in _buffer(self, n)
#     441             return
#     442         record_buffer = deque()
# --> 443         for record in self:
#     444             record_buffer.append(record)
#     445             if n is not None and len(record_buffer) >= n:
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/work/result.py in __iter__(self)
#     391                 yield self._record_buffer.popleft()
#     392             elif self._streaming:
# --> 393                 self._connection.fetch_message()
#     394             elif self._discarding:
#     395                 self._discard()
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_common.py in inner(*args, **kwargs)
#     179             def inner(*args, **kwargs):
#     180                 try:
# --> 181                     func(*args, **kwargs)
#     182                 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     183                     assert not asyncio.iscoroutinefunction(self.__on_error)
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_bolt.py in fetch_message(self)
#     975             hydration_hooks=self.responses[0].hydration_hooks
#     976         )
# --> 977         res = self._process_message(tag, fields)
#     978         self.idle_since = monotonic()
#     979         return res
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_bolt5.py in _process_message(self, tag, fields)
#     464             self._server_state_manager.state = self.bolt_states.FAILED
#     465             try:
# --> 466                 response.on_failure(summary_metadata or {})
#     467             except (ServiceUnavailable, DatabaseUnavailable):
#     468                 if self.pool:
#
# /usr/local/lib/python3.10/dist-packages/neo4j/_sync/io/_common.py in on_failure(self, metadata)
#     249         handler = self.handlers.get("on_summary")
#     250         Util.callback(handler)
# --> 251         raise Neo4jError.hydrate(**metadata)
#     252
#     253     def on_ignored(self, metadata=None):
#
# ClientError: {code: Neo.ClientError.Procedure.ProcedureCallFailed} {message: Failed to invoke procedure `db.index.fulltext.queryNodes`: Caused by: java.lang.IllegalArgumentException: There is no such fulltext schema index: entity}
